# %%
# Command to reload all modules before executing the code
# %load_ext autoreload 
# %autoreload 2

# %%
# ML libraries
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.metrics import accuracy_score
import xgboost as xgb
# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# Utils
import os
import sys
from collections import defaultdict
from tqdm import tqdm
import warnings
from typing import List, Dict, Any, Tuple, Union, Optional, Callable, TypeVar
# Project modules
from src.data_loading import load_dataframe_teamfeatures, load_dataframe_playersfeatures

warnings.filterwarnings('ignore')
# Out:
# C:\Users\timot\AppData\Local\Temp\ipykernel_22924\2406528269.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
print("Teamfeatures :")
df_teamfeatures_train = load_dataframe_teamfeatures("train")
print("Team features train shape: ", df_teamfeatures_train.shape)
df_teamfeatures_test = load_dataframe_teamfeatures("test")
print("Team features test shape: ", df_teamfeatures_test.shape)

print()
print("Playersfeatures :")
df_playersfeatures_train_home, df_playersfeatures_train_away = load_dataframe_playersfeatures("train")
print("Players features train home shape: ", df_playersfeatures_train_home.shape)
print("Players features train away shape: ", df_playersfeatures_train_away.shape)
df_playersfeatures_test_home, df_playersfeatures_test_away = load_dataframe_playersfeatures("test")
print("Players features test home shape: ", df_playersfeatures_test_home.shape)
print("Players features test away shape: ", df_playersfeatures_test_away.shape)
# Out:
# Teamfeatures :
# Team features train shape:  (12303, 286)
# Team features test shape:  (25368, 282)
#
# Playersfeatures :
# Players features train home shape:  (237079, 307)
# Players features train away shape:  (236132, 307)
# Players features test home shape:  (509816, 304)
# Players features test away shape:  (504626, 304)

# %%
print("Number of data for train teamfeatures: ", df_teamfeatures_train.shape[0])
print("Number of missing values per column for train teamfeatures, for non-zero values, sorted by number of missing values in descending order")
serie = df_teamfeatures_train.isnull().sum()
serie = serie.sort_values(ascending=False)
for i in range(len(serie)):
    print(f"{serie.index[i]}: {serie[i]}, i.e. {serie[i] / df_teamfeatures_train.shape[0] * 100:.2f}%")
# Out:
# Number of data for train teamfeatures:  12303
# Number of missing values per column for train teamfeatures, for non-zero values, sorted by number of missing values in descending order
# HOME_TEAM_INJURIES_5_last_match_std: 3318, i.e. 26.97%
# AWAY_TEAM_INJURIES_5_last_match_std: 3313, i.e. 26.93%
# AWAY_TEAM_INJURIES_5_last_match_sum: 2933, i.e. 23.84%
# AWAY_TEAM_INJURIES_5_last_match_average: 2932, i.e. 23.83%
# HOME_TEAM_INJURIES_5_last_match_sum: 2932, i.e. 23.83%
# HOME_TEAM_INJURIES_5_last_match_average: 2931, i.e. 23.82%
# AWAY_TEAM_INJURIES_season_std: 2926, i.e. 23.78%
# HOME_TEAM_INJURIES_season_std: 2924, i.e. 23.77%
# AWAY_TEAM_INJURIES_season_sum: 1961, i.e. 15.94%
# AWAY_TEAM_INJURIES_season_average: 1960, i.e. 15.93%
# HOME_TEAM_INJURIES_season_sum: 1960, i.e. 15.93%
# HOME_TEAM_INJURIES_season_average: 1959, i.e. 15.92%
# AWAY_TEAM_BALL_SAFE_5_last_match_std: 1836, i.e. 14.92%
# HOME_TEAM_BALL_SAFE_5_last_match_std: 1795, i.e. 14.59%
# HOME_TEAM_PASSES_5_last_match_std: 1589, i.e. 12.92%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_std: 1589, i.e. 12.92%
# AWAY_TEAM_PASSES_5_last_match_std: 1588, i.e. 12.91%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_std: 1588, i.e. 12.91%
# AWAY_TEAM_PASSES_season_std: 1529, i.e. 12.43%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_std: 1529, i.e. 12.43%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_std: 1529, i.e. 12.43%
# HOME_TEAM_PASSES_season_std: 1529, i.e. 12.43%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_average: 1528, i.e. 12.42%
# AWAY_TEAM_PASSES_5_last_match_average: 1527, i.e. 12.41%
# AWAY_TEAM_PASSES_5_last_match_sum: 1527, i.e. 12.41%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_average: 1525, i.e. 12.40%
# HOME_TEAM_PASSES_5_last_match_average: 1524, i.e. 12.39%
# HOME_TEAM_PASSES_5_last_match_sum: 1524, i.e. 12.39%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_average: 1418, i.e. 11.53%
# AWAY_TEAM_PASSES_season_average: 1417, i.e. 11.52%
# AWAY_TEAM_PASSES_season_sum: 1417, i.e. 11.52%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_average: 1414, i.e. 11.49%
# HOME_TEAM_PASSES_season_sum: 1413, i.e. 11.49%
# HOME_TEAM_PASSES_season_average: 1413, i.e. 11.49%
# HOME_TEAM_SHOTS_OUTSIDEBOX_5_last_match_std: 1408, i.e. 11.44%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_5_last_match_std: 1407, i.e. 11.44%
# HOME_TEAM_SHOTS_INSIDEBOX_5_last_match_std: 1407, i.e. 11.44%
# HOME_TEAM_SUCCESSFUL_PASSES_5_last_match_std: 1407, i.e. 11.44%
# AWAY_TEAM_SHOTS_INSIDEBOX_5_last_match_std: 1406, i.e. 11.43%
# AWAY_TEAM_SUCCESSFUL_PASSES_5_last_match_std: 1406, i.e. 11.43%
# HOME_TEAM_SHOTS_OUTSIDEBOX_season_std: 1400, i.e. 11.38%
# HOME_TEAM_SHOTS_INSIDEBOX_season_std: 1399, i.e. 11.37%
# HOME_TEAM_SUCCESSFUL_PASSES_season_std: 1399, i.e. 11.37%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_season_std: 1397, i.e. 11.35%
# AWAY_TEAM_SHOTS_INSIDEBOX_season_std: 1396, i.e. 11.35%
# AWAY_TEAM_SUCCESSFUL_PASSES_season_std: 1396, i.e. 11.35%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_5_last_match_sum: 1391, i.e. 11.31%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_5_last_match_average: 1390, i.e. 11.30%
# HOME_TEAM_SHOTS_OUTSIDEBOX_5_last_match_sum: 1390, i.e. 11.30%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_season_sum: 1389, i.e. 11.29%
# HOME_TEAM_SHOTS_OUTSIDEBOX_5_last_match_average: 1389, i.e. 11.29%
# AWAY_TEAM_SHOTS_INSIDEBOX_5_last_match_sum: 1388, i.e. 11.28%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_season_average: 1388, i.e. 11.28%
# AWAY_TEAM_SHOTS_INSIDEBOX_5_last_match_average: 1388, i.e. 11.28%
# HOME_TEAM_SHOTS_INSIDEBOX_5_last_match_sum: 1388, i.e. 11.28%
# HOME_TEAM_SHOTS_INSIDEBOX_5_last_match_average: 1388, i.e. 11.28%
# HOME_TEAM_SUCCESSFUL_PASSES_5_last_match_sum: 1387, i.e. 11.27%
# HOME_TEAM_SHOTS_OUTSIDEBOX_season_sum: 1387, i.e. 11.27%
# HOME_TEAM_SUCCESSFUL_PASSES_5_last_match_average: 1387, i.e. 11.27%
# AWAY_TEAM_SUCCESSFUL_PASSES_5_last_match_sum: 1387, i.e. 11.27%
# AWAY_TEAM_SUCCESSFUL_PASSES_5_last_match_average: 1387, i.e. 11.27%
# AWAY_TEAM_SHOTS_INSIDEBOX_season_sum: 1386, i.e. 11.27%
# AWAY_TEAM_SHOTS_INSIDEBOX_season_average: 1386, i.e. 11.27%
# HOME_TEAM_SHOTS_OUTSIDEBOX_season_average: 1386, i.e. 11.27%
# HOME_TEAM_SHOTS_INSIDEBOX_season_sum: 1385, i.e. 11.26%
# AWAY_TEAM_SUCCESSFUL_PASSES_season_average: 1385, i.e. 11.26%
# AWAY_TEAM_SUCCESSFUL_PASSES_season_sum: 1385, i.e. 11.26%
# HOME_TEAM_SHOTS_INSIDEBOX_season_average: 1385, i.e. 11.26%
# HOME_TEAM_SUCCESSFUL_PASSES_season_average: 1384, i.e. 11.25%
# HOME_TEAM_SUCCESSFUL_PASSES_season_sum: 1384, i.e. 11.25%
# HOME_TEAM_BALL_SAFE_5_last_match_average: 1172, i.e. 9.53%
# HOME_TEAM_BALL_SAFE_5_last_match_sum: 1172, i.e. 9.53%
# AWAY_TEAM_BALL_SAFE_5_last_match_sum: 1169, i.e. 9.50%
# AWAY_TEAM_BALL_SAFE_5_last_match_average: 1169, i.e. 9.50%
# HOME_TEAM_OFFSIDES_5_last_match_std: 1006, i.e. 8.18%
# AWAY_TEAM_OFFSIDES_5_last_match_std: 1005, i.e. 8.17%
# HOME_TEAM_SAVES_5_last_match_std: 1003, i.e. 8.15%
# AWAY_TEAM_SAVES_5_last_match_std: 1003, i.e. 8.15%
# HOME_TEAM_FOULS_5_last_match_std: 996, i.e. 8.10%
# AWAY_TEAM_FOULS_5_last_match_std: 994, i.e. 8.08%
# AWAY_TEAM_BALL_SAFE_season_std: 989, i.e. 8.04%
# HOME_TEAM_BALL_SAFE_season_std: 984, i.e. 8.00%
# AWAY_TEAM_SHOTS_TOTAL_5_last_match_std: 974, i.e. 7.92%
# HOME_TEAM_SHOTS_TOTAL_5_last_match_std: 972, i.e. 7.90%
# HOME_TEAM_SAVES_season_std: 931, i.e. 7.57%
# HOME_TEAM_OFFSIDES_season_std: 931, i.e. 7.57%
# AWAY_TEAM_OFFSIDES_5_last_match_sum: 929, i.e. 7.55%
# HOME_TEAM_FOULS_season_std: 929, i.e. 7.55%
# AWAY_TEAM_OFFSIDES_5_last_match_average: 929, i.e. 7.55%
# HOME_TEAM_OFFSIDES_5_last_match_average: 928, i.e. 7.54%
# HOME_TEAM_OFFSIDES_5_last_match_sum: 928, i.e. 7.54%
# AWAY_TEAM_OFFSIDES_season_std: 926, i.e. 7.53%
# HOME_TEAM_SAVES_5_last_match_average: 926, i.e. 7.53%
# AWAY_TEAM_SAVES_5_last_match_sum: 926, i.e. 7.53%
# AWAY_TEAM_SAVES_5_last_match_average: 926, i.e. 7.53%
# AWAY_TEAM_FOULS_season_std: 926, i.e. 7.53%
# AWAY_TEAM_SAVES_season_std: 926, i.e. 7.53%
# HOME_TEAM_SAVES_5_last_match_sum: 926, i.e. 7.53%
# AWAY_TEAM_FOULS_5_last_match_sum: 916, i.e. 7.45%
# AWAY_TEAM_FOULS_5_last_match_average: 916, i.e. 7.45%
# HOME_TEAM_FOULS_5_last_match_average: 912, i.e. 7.41%
# HOME_TEAM_FOULS_5_last_match_sum: 912, i.e. 7.41%
# AWAY_TEAM_OFFSIDES_season_sum: 788, i.e. 6.40%
# AWAY_TEAM_OFFSIDES_season_average: 788, i.e. 6.40%
# AWAY_TEAM_SAVES_season_average: 785, i.e. 6.38%
# AWAY_TEAM_SAVES_season_sum: 785, i.e. 6.38%
# HOME_TEAM_OFFSIDES_season_sum: 783, i.e. 6.36%
# HOME_TEAM_OFFSIDES_season_average: 783, i.e. 6.36%
# HOME_TEAM_SAVES_season_sum: 780, i.e. 6.34%
# HOME_TEAM_SAVES_season_average: 780, i.e. 6.34%
# AWAY_TEAM_FOULS_season_average: 763, i.e. 6.20%
# AWAY_TEAM_FOULS_season_sum: 763, i.e. 6.20%
# HOME_TEAM_FOULS_season_average: 757, i.e. 6.15%
# HOME_TEAM_FOULS_season_sum: 757, i.e. 6.15%
# AWAY_TEAM_SHOTS_TOTAL_5_last_match_sum: 677, i.e. 5.50%
# AWAY_TEAM_SHOTS_TOTAL_5_last_match_average: 677, i.e. 5.50%
# HOME_TEAM_SHOTS_TOTAL_5_last_match_sum: 675, i.e. 5.49%
# HOME_TEAM_SHOTS_TOTAL_5_last_match_average: 675, i.e. 5.49%
# AWAY_TEAM_SHOTS_TOTAL_season_std: 586, i.e. 4.76%
# HOME_TEAM_SHOTS_TOTAL_season_std: 586, i.e. 4.76%
# HOME_TEAM_BALL_SAFE_season_average: 363, i.e. 2.95%
# HOME_TEAM_BALL_SAFE_season_sum: 363, i.e. 2.95%
# AWAY_TEAM_BALL_SAFE_season_average: 362, i.e. 2.94%
# AWAY_TEAM_BALL_SAFE_season_sum: 362, i.e. 2.94%
# HOME_TEAM_SHOTS_TOTAL_season_average: 260, i.e. 2.11%
# HOME_TEAM_SHOTS_TOTAL_season_sum: 260, i.e. 2.11%
# AWAY_TEAM_SHOTS_TOTAL_season_sum: 259, i.e. 2.11%
# AWAY_TEAM_SHOTS_TOTAL_season_average: 259, i.e. 2.11%
# AWAY_TEAM_SUBSTITUTIONS_5_last_match_sum: 92, i.e. 0.75%
# AWAY_TEAM_SUBSTITUTIONS_5_last_match_average: 92, i.e. 0.75%
# HOME_TEAM_SUBSTITUTIONS_5_last_match_average: 92, i.e. 0.75%
# HOME_TEAM_SUBSTITUTIONS_5_last_match_sum: 92, i.e. 0.75%
# AWAY_TEAM_SUBSTITUTIONS_5_last_match_std: 91, i.e. 0.74%
# HOME_TEAM_SUBSTITUTIONS_5_last_match_std: 91, i.e. 0.74%
# HOME_TEAM_SUBSTITUTIONS_season_average: 69, i.e. 0.56%
# AWAY_TEAM_SUBSTITUTIONS_season_average: 69, i.e. 0.56%
# AWAY_TEAM_SUBSTITUTIONS_season_std: 68, i.e. 0.55%
# HOME_TEAM_SUBSTITUTIONS_season_std: 68, i.e. 0.55%
# AWAY_TEAM_REDCARDS_5_last_match_average: 65, i.e. 0.53%
# HOME_TEAM_REDCARDS_5_last_match_sum: 65, i.e. 0.53%
# AWAY_TEAM_REDCARDS_5_last_match_sum: 65, i.e. 0.53%
# HOME_TEAM_REDCARDS_5_last_match_average: 65, i.e. 0.53%
# HOME_TEAM_REDCARDS_5_last_match_std: 63, i.e. 0.51%
# AWAY_TEAM_REDCARDS_5_last_match_std: 63, i.e. 0.51%
# HOME_TEAM_SUBSTITUTIONS_season_sum: 46, i.e. 0.37%
# AWAY_TEAM_SUBSTITUTIONS_season_sum: 46, i.e. 0.37%
# AWAY_TEAM_REDCARDS_season_average: 34, i.e. 0.28%
# HOME_TEAM_REDCARDS_season_sum: 34, i.e. 0.28%
# AWAY_TEAM_REDCARDS_season_sum: 34, i.e. 0.28%
# HOME_TEAM_REDCARDS_season_average: 34, i.e. 0.28%
# HOME_TEAM_REDCARDS_season_std: 32, i.e. 0.26%
# AWAY_TEAM_REDCARDS_season_std: 32, i.e. 0.26%
# HOME_TEAM_PENALTIES_season_sum: 16, i.e. 0.13%
# AWAY_TEAM_PENALTIES_5_last_match_average: 16, i.e. 0.13%
# HOME_TEAM_PENALTIES_season_average: 16, i.e. 0.13%
# HOME_TEAM_PENALTIES_5_last_match_average: 16, i.e. 0.13%
# HOME_TEAM_PENALTIES_5_last_match_sum: 16, i.e. 0.13%
# AWAY_TEAM_PENALTIES_season_average: 16, i.e. 0.13%
# AWAY_TEAM_PENALTIES_season_sum: 16, i.e. 0.13%
# AWAY_TEAM_PENALTIES_5_last_match_sum: 16, i.e. 0.13%
# HOME_TEAM_GAME_DRAW_season_sum: 15, i.e. 0.12%
# AWAY_TEAM_GAME_DRAW_season_sum: 15, i.e. 0.12%
# HOME_TEAM_GAME_DRAW_5_last_match_sum: 15, i.e. 0.12%
# AWAY_TEAM_GAME_DRAW_5_last_match_average: 15, i.e. 0.12%
# HOME_TEAM_GAME_DRAW_season_average: 15, i.e. 0.12%
# HOME_TEAM_GAME_DRAW_5_last_match_average: 15, i.e. 0.12%
# AWAY_TEAM_GAME_DRAW_5_last_match_sum: 15, i.e. 0.12%
# AWAY_TEAM_GAME_DRAW_season_average: 15, i.e. 0.12%
# AWAY_TEAM_PENALTIES_season_std: 13, i.e. 0.11%
# HOME_TEAM_PENALTIES_season_std: 13, i.e. 0.11%
# HOME_TEAM_PENALTIES_5_last_match_std: 13, i.e. 0.11%
# AWAY_TEAM_PENALTIES_5_last_match_std: 13, i.e. 0.11%
# AWAY_TEAM_GAME_LOST_season_average: 9, i.e. 0.07%
# HOME_TEAM_GAME_LOST_5_last_match_sum: 9, i.e. 0.07%
# HOME_TEAM_GAME_LOST_5_last_match_average: 9, i.e. 0.07%
# HOME_TEAM_GAME_LOST_season_average: 9, i.e. 0.07%
# AWAY_TEAM_GAME_LOST_5_last_match_average: 9, i.e. 0.07%
# AWAY_TEAM_GAME_LOST_season_sum: 9, i.e. 0.07%
# AWAY_TEAM_GAME_LOST_5_last_match_sum: 9, i.e. 0.07%
# HOME_TEAM_GAME_LOST_season_sum: 9, i.e. 0.07%
# AWAY_TEAM_GAME_WON_season_average: 8, i.e. 0.07%
# AWAY_TEAM_GAME_WON_5_last_match_average: 8, i.e. 0.07%
# HOME_TEAM_GAME_WON_5_last_match_sum: 8, i.e. 0.07%
# HOME_TEAM_GAME_WON_season_average: 8, i.e. 0.07%
# AWAY_TEAM_GAME_WON_5_last_match_sum: 8, i.e. 0.07%
# AWAY_TEAM_GAME_WON_season_sum: 8, i.e. 0.07%
# HOME_TEAM_GAME_WON_5_last_match_average: 8, i.e. 0.07%
# HOME_TEAM_GAME_WON_season_sum: 8, i.e. 0.07%
# AWAY_TEAM_YELLOWCARDS_5_last_match_sum: 5, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_season_average: 5, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_5_last_match_sum: 5, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_5_last_match_average: 5, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_5_last_match_average: 5, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_season_sum: 5, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_season_average: 5, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_season_sum: 5, i.e. 0.04%
# AWAY_TEAM_GOALS_5_last_match_sum: 4, i.e. 0.03%
# HOME_TEAM_GOALS_season_sum: 4, i.e. 0.03%
# AWAY_TEAM_GOALS_season_average: 4, i.e. 0.03%
# HOME_TEAM_GOALS_5_last_match_average: 4, i.e. 0.03%
# HOME_TEAM_GOALS_5_last_match_sum: 4, i.e. 0.03%
# AWAY_TEAM_GOALS_5_last_match_average: 4, i.e. 0.03%
# HOME_TEAM_GOALS_season_average: 4, i.e. 0.03%
# AWAY_TEAM_GOALS_season_sum: 4, i.e. 0.03%
# AWAY_TEAM_GOALS_season_std: 2, i.e. 0.02%
# AWAY_TEAM_SHOTS_ON_TARGET_5_last_match_sum: 2, i.e. 0.02%
# AWAY_TEAM_BALL_POSSESSION_5_last_match_average: 2, i.e. 0.02%
# AWAY_TEAM_GOALS_5_last_match_std: 2, i.e. 0.02%
# AWAY_TEAM_SHOTS_ON_TARGET_5_last_match_average: 2, i.e. 0.02%
# HOME_TEAM_SHOTS_ON_TARGET_5_last_match_sum: 2, i.e. 0.02%
# AWAY_TEAM_BALL_POSSESSION_season_std: 2, i.e. 0.02%
# HOME_TEAM_GOALS_season_std: 2, i.e. 0.02%
# AWAY_TEAM_BALL_POSSESSION_5_last_match_std: 2, i.e. 0.02%
# HOME_TEAM_BALL_POSSESSION_season_std: 2, i.e. 0.02%
# HOME_TEAM_BALL_POSSESSION_5_last_match_std: 2, i.e. 0.02%
# HOME_TEAM_GOALS_5_last_match_std: 2, i.e. 0.02%
# HOME_TEAM_SHOTS_ON_TARGET_5_last_match_average: 2, i.e. 0.02%
# AWAY_TEAM_SHOTS_ON_TARGET_season_sum: 2, i.e. 0.02%
# AWAY_TEAM_SHOTS_ON_TARGET_season_average: 2, i.e. 0.02%
# HOME_TEAM_SHOTS_ON_TARGET_season_average: 2, i.e. 0.02%
# AWAY_TEAM_BALL_POSSESSION_season_average: 2, i.e. 0.02%
# HOME_TEAM_SHOTS_ON_TARGET_season_sum: 2, i.e. 0.02%
# HOME_TEAM_CORNERS_season_average: 1, i.e. 0.01%
# AWAY_TEAM_YELLOWCARDS_5_last_match_std: 1, i.e. 0.01%
# HOME_TEAM_YELLOWCARDS_season_std: 1, i.e. 0.01%
# HOME_TEAM_CORNERS_season_sum: 1, i.e. 0.01%
# HOME_TEAM_BALL_POSSESSION_season_average: 1, i.e. 0.01%
# AWAY_TEAM_YELLOWCARDS_season_std: 1, i.e. 0.01%
# HOME_TEAM_CORNERS_5_last_match_sum: 1, i.e. 0.01%
# AWAY_TEAM_CORNERS_5_last_match_sum: 1, i.e. 0.01%
# HOME_TEAM_BALL_POSSESSION_5_last_match_average: 1, i.e. 0.01%
# HOME_TEAM_YELLOWCARDS_5_last_match_std: 1, i.e. 0.01%
# AWAY_TEAM_CORNERS_season_sum: 1, i.e. 0.01%
# AWAY_TEAM_CORNERS_5_last_match_average: 1, i.e. 0.01%
# AWAY_TEAM_CORNERS_season_average: 1, i.e. 0.01%
# HOME_TEAM_CORNERS_5_last_match_average: 1, i.e. 0.01%
# AWAY_TEAM_CORNERS_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_ON_TARGET_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_5_last_match_average: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_5_last_match_average: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_5_last_match_std: 0, i.e. 0.00%
# HOME_ID: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_5_last_match_average: 0, i.e. 0.00%
# HOME_TEAM_CORNERS_season_std: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_5_last_match_average: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_5_last_match_average: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_5_last_match_average: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_5_last_match_sum: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_5_last_match_sum: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_5_last_match_sum: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_season_std: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_season_std: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_ON_TARGET_season_std: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_5_last_match_sum: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_season_std: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_season_average: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_season_average: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_season_average: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_season_sum: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_season_sum: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_season_sum: 0, i.e. 0.00%
# HOME_TEAM_NAME: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_5_last_match_std: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_ON_TARGET_5_last_match_std: 0, i.e. 0.00%
# HOME_TEAM_CORNERS_5_last_match_std: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_5_last_match_sum: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_5_last_match_sum: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_season_std: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_season_std: 0, i.e. 0.00%
# AWAY_TEAM_CORNERS_season_std: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_ON_TARGET_season_std: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_season_std: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_season_average: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_season_average: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_season_average: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_season_sum: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_season_sum: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_season_sum: 0, i.e. 0.00%
# AWAY_TEAM_NAME: 0, i.e. 0.00%
# AWAY_LEAGUE: 0, i.e. 0.00%
# HOME_LEAGUE: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_5_last_match_std: 0, i.e. 0.00%
# AWAY_ID: 0, i.e. 0.00%

# %%
print("Number of data for test teamfeatures : ", df_teamfeatures_test.shape[0])
print("Number of missing values per column for test teamfeatures, sorted by number of missing values in descending order")
serie = df_teamfeatures_test.isnull().sum()
serie = serie.sort_values(ascending=False)
for i in range(len(serie)):
    print(f"{serie.index[i]}: {serie[i]}, i.e. {serie[i] / df_teamfeatures_test.shape[0] * 100:.2f}%")
# Out:
# Number of data for test teamfeatures :  25368
# Number of missing values per column for test teamfeatures, sorted by number of missing values in descending order
# AWAY_TEAM_INJURIES_5_last_match_std: 3676, i.e. 14.49%
# HOME_TEAM_INJURIES_5_last_match_std: 3634, i.e. 14.33%
# HOME_TEAM_BALL_SAFE_5_last_match_std: 2893, i.e. 11.40%
# AWAY_TEAM_BALL_SAFE_5_last_match_std: 2890, i.e. 11.39%
# HOME_TEAM_INJURIES_5_last_match_sum: 2705, i.e. 10.66%
# HOME_TEAM_INJURIES_5_last_match_average: 2700, i.e. 10.64%
# AWAY_TEAM_INJURIES_5_last_match_sum: 2692, i.e. 10.61%
# AWAY_TEAM_INJURIES_5_last_match_average: 2687, i.e. 10.59%
# AWAY_TEAM_INJURIES_season_std: 2481, i.e. 9.78%
# HOME_TEAM_INJURIES_season_std: 2473, i.e. 9.75%
# HOME_TEAM_BALL_SAFE_5_last_match_sum: 2254, i.e. 8.89%
# HOME_TEAM_BALL_SAFE_5_last_match_average: 2254, i.e. 8.89%
# AWAY_TEAM_BALL_SAFE_5_last_match_average: 2250, i.e. 8.87%
# AWAY_TEAM_BALL_SAFE_5_last_match_sum: 2250, i.e. 8.87%
# HOME_TEAM_BALL_SAFE_season_std: 2091, i.e. 8.24%
# AWAY_TEAM_BALL_SAFE_season_std: 2083, i.e. 8.21%
# HOME_TEAM_INJURIES_season_sum: 2000, i.e. 7.88%
# AWAY_TEAM_INJURIES_season_sum: 1996, i.e. 7.87%
# HOME_TEAM_INJURIES_season_average: 1995, i.e. 7.86%
# AWAY_TEAM_INJURIES_season_average: 1991, i.e. 7.85%
# HOME_TEAM_BALL_SAFE_season_sum: 1793, i.e. 7.07%
# HOME_TEAM_BALL_SAFE_season_average: 1793, i.e. 7.07%
# AWAY_TEAM_BALL_SAFE_season_sum: 1792, i.e. 7.06%
# AWAY_TEAM_BALL_SAFE_season_average: 1792, i.e. 7.06%
# HOME_TEAM_PASSES_5_last_match_std: 1249, i.e. 4.92%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_std: 1249, i.e. 4.92%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_std: 1248, i.e. 4.92%
# AWAY_TEAM_PASSES_5_last_match_std: 1248, i.e. 4.92%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_average: 1199, i.e. 4.73%
# HOME_TEAM_PASSES_5_last_match_sum: 1199, i.e. 4.73%
# HOME_TEAM_PASSES_5_last_match_average: 1199, i.e. 4.73%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_average: 1199, i.e. 4.73%
# AWAY_TEAM_PASSES_5_last_match_sum: 1199, i.e. 4.73%
# AWAY_TEAM_PASSES_5_last_match_average: 1199, i.e. 4.73%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_std: 1196, i.e. 4.71%
# HOME_TEAM_PASSES_season_std: 1196, i.e. 4.71%
# AWAY_TEAM_PASSES_season_std: 1189, i.e. 4.69%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_std: 1189, i.e. 4.69%
# HOME_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_average: 1115, i.e. 4.40%
# HOME_TEAM_PASSES_season_average: 1115, i.e. 4.40%
# HOME_TEAM_PASSES_season_sum: 1115, i.e. 4.40%
# AWAY_TEAM_PASSES_season_sum: 1108, i.e. 4.37%
# AWAY_TEAM_PASSES_season_average: 1108, i.e. 4.37%
# AWAY_TEAM_SUCCESSFUL_PASSES_PERCENTAGE_season_average: 1108, i.e. 4.37%
# HOME_TEAM_SHOTS_OUTSIDEBOX_5_last_match_std: 1066, i.e. 4.20%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_5_last_match_std: 1065, i.e. 4.20%
# HOME_TEAM_SUCCESSFUL_PASSES_5_last_match_std: 1059, i.e. 4.17%
# HOME_TEAM_SHOTS_INSIDEBOX_5_last_match_std: 1059, i.e. 4.17%
# AWAY_TEAM_SUCCESSFUL_PASSES_5_last_match_std: 1058, i.e. 4.17%
# AWAY_TEAM_SHOTS_INSIDEBOX_5_last_match_std: 1058, i.e. 4.17%
# HOME_TEAM_SHOTS_OUTSIDEBOX_5_last_match_average: 1053, i.e. 4.15%
# HOME_TEAM_SHOTS_OUTSIDEBOX_5_last_match_sum: 1053, i.e. 4.15%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_5_last_match_average: 1053, i.e. 4.15%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_5_last_match_sum: 1053, i.e. 4.15%
# HOME_TEAM_SHOTS_INSIDEBOX_5_last_match_average: 1042, i.e. 4.11%
# AWAY_TEAM_SHOTS_INSIDEBOX_5_last_match_average: 1042, i.e. 4.11%
# AWAY_TEAM_SHOTS_INSIDEBOX_5_last_match_sum: 1042, i.e. 4.11%
# HOME_TEAM_SHOTS_INSIDEBOX_5_last_match_sum: 1042, i.e. 4.11%
# HOME_TEAM_SUCCESSFUL_PASSES_5_last_match_sum: 1040, i.e. 4.10%
# AWAY_TEAM_SUCCESSFUL_PASSES_5_last_match_sum: 1040, i.e. 4.10%
# AWAY_TEAM_SUCCESSFUL_PASSES_5_last_match_average: 1040, i.e. 4.10%
# HOME_TEAM_SUCCESSFUL_PASSES_5_last_match_average: 1040, i.e. 4.10%
# HOME_TEAM_SHOTS_OUTSIDEBOX_season_std: 938, i.e. 3.70%
# HOME_TEAM_SHOTS_INSIDEBOX_season_std: 938, i.e. 3.70%
# HOME_TEAM_SUCCESSFUL_PASSES_season_std: 938, i.e. 3.70%
# AWAY_TEAM_SUCCESSFUL_PASSES_season_std: 934, i.e. 3.68%
# AWAY_TEAM_SHOTS_INSIDEBOX_season_std: 934, i.e. 3.68%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_season_std: 934, i.e. 3.68%
# HOME_TEAM_SHOTS_OUTSIDEBOX_season_sum: 930, i.e. 3.67%
# HOME_TEAM_SHOTS_OUTSIDEBOX_season_average: 930, i.e. 3.67%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_season_average: 927, i.e. 3.65%
# AWAY_TEAM_SHOTS_OUTSIDEBOX_season_sum: 927, i.e. 3.65%
# HOME_TEAM_SHOTS_INSIDEBOX_season_average: 926, i.e. 3.65%
# HOME_TEAM_SHOTS_INSIDEBOX_season_sum: 926, i.e. 3.65%
# HOME_TEAM_SUCCESSFUL_PASSES_season_average: 924, i.e. 3.64%
# HOME_TEAM_SUCCESSFUL_PASSES_season_sum: 924, i.e. 3.64%
# AWAY_TEAM_SHOTS_INSIDEBOX_season_sum: 923, i.e. 3.64%
# AWAY_TEAM_SHOTS_INSIDEBOX_season_average: 923, i.e. 3.64%
# AWAY_TEAM_SUCCESSFUL_PASSES_season_sum: 921, i.e. 3.63%
# AWAY_TEAM_SUCCESSFUL_PASSES_season_average: 921, i.e. 3.63%
# HOME_TEAM_OFFSIDES_5_last_match_std: 854, i.e. 3.37%
# AWAY_TEAM_OFFSIDES_5_last_match_std: 851, i.e. 3.35%
# HOME_TEAM_SAVES_5_last_match_std: 850, i.e. 3.35%
# AWAY_TEAM_SAVES_5_last_match_std: 848, i.e. 3.34%
# HOME_TEAM_FOULS_5_last_match_std: 759, i.e. 2.99%
# AWAY_TEAM_FOULS_5_last_match_std: 758, i.e. 2.99%
# HOME_TEAM_SHOTS_TOTAL_5_last_match_std: 756, i.e. 2.98%
# AWAY_TEAM_SHOTS_TOTAL_5_last_match_std: 754, i.e. 2.97%
# AWAY_TEAM_OFFSIDES_5_last_match_sum: 684, i.e. 2.70%
# AWAY_TEAM_OFFSIDES_5_last_match_average: 683, i.e. 2.69%
# HOME_TEAM_OFFSIDES_5_last_match_sum: 678, i.e. 2.67%
# AWAY_TEAM_SAVES_5_last_match_sum: 677, i.e. 2.67%
# AWAY_TEAM_SAVES_5_last_match_average: 677, i.e. 2.67%
# HOME_TEAM_OFFSIDES_5_last_match_average: 677, i.e. 2.67%
# HOME_TEAM_OFFSIDES_season_std: 673, i.e. 2.65%
# HOME_TEAM_SAVES_5_last_match_sum: 670, i.e. 2.64%
# HOME_TEAM_SAVES_5_last_match_average: 670, i.e. 2.64%
# AWAY_TEAM_OFFSIDES_season_std: 666, i.e. 2.63%
# HOME_TEAM_SAVES_season_std: 666, i.e. 2.63%
# AWAY_TEAM_SAVES_season_std: 660, i.e. 2.60%
# AWAY_TEAM_FOULS_5_last_match_sum: 592, i.e. 2.33%
# AWAY_TEAM_FOULS_5_last_match_average: 592, i.e. 2.33%
# HOME_TEAM_FOULS_5_last_match_sum: 583, i.e. 2.30%
# HOME_TEAM_FOULS_5_last_match_average: 583, i.e. 2.30%
# HOME_TEAM_FOULS_season_std: 557, i.e. 2.20%
# AWAY_TEAM_SHOTS_TOTAL_5_last_match_average: 555, i.e. 2.19%
# AWAY_TEAM_SHOTS_TOTAL_5_last_match_sum: 555, i.e. 2.19%
# AWAY_TEAM_FOULS_season_std: 553, i.e. 2.18%
# HOME_TEAM_SHOTS_TOTAL_5_last_match_sum: 548, i.e. 2.16%
# HOME_TEAM_SHOTS_TOTAL_5_last_match_average: 548, i.e. 2.16%
# HOME_TEAM_SHOTS_TOTAL_season_std: 519, i.e. 2.05%
# AWAY_TEAM_SHOTS_TOTAL_season_std: 516, i.e. 2.03%
# AWAY_TEAM_OFFSIDES_season_sum: 381, i.e. 1.50%
# AWAY_TEAM_OFFSIDES_season_average: 380, i.e. 1.50%
# HOME_TEAM_OFFSIDES_season_sum: 375, i.e. 1.48%
# HOME_TEAM_OFFSIDES_season_average: 374, i.e. 1.47%
# AWAY_TEAM_SAVES_season_sum: 373, i.e. 1.47%
# AWAY_TEAM_SAVES_season_average: 373, i.e. 1.47%
# HOME_TEAM_SAVES_season_sum: 365, i.e. 1.44%
# HOME_TEAM_SAVES_season_average: 365, i.e. 1.44%
# AWAY_TEAM_SUBSTITUTIONS_5_last_match_std: 351, i.e. 1.38%
# HOME_TEAM_SUBSTITUTIONS_5_last_match_std: 346, i.e. 1.36%
# HOME_TEAM_SUBSTITUTIONS_5_last_match_average: 333, i.e. 1.31%
# AWAY_TEAM_SUBSTITUTIONS_5_last_match_average: 332, i.e. 1.31%
# HOME_TEAM_SUBSTITUTIONS_5_last_match_sum: 328, i.e. 1.29%
# AWAY_TEAM_SUBSTITUTIONS_5_last_match_sum: 327, i.e. 1.29%
# AWAY_TEAM_FOULS_season_sum: 291, i.e. 1.15%
# AWAY_TEAM_FOULS_season_average: 291, i.e. 1.15%
# HOME_TEAM_FOULS_season_sum: 282, i.e. 1.11%
# HOME_TEAM_FOULS_season_average: 282, i.e. 1.11%
# AWAY_TEAM_SHOTS_TOTAL_season_average: 259, i.e. 1.02%
# AWAY_TEAM_SHOTS_TOTAL_season_sum: 259, i.e. 1.02%
# HOME_TEAM_SHOTS_TOTAL_season_sum: 244, i.e. 0.96%
# HOME_TEAM_SHOTS_TOTAL_season_average: 244, i.e. 0.96%
# HOME_TEAM_PENALTIES_5_last_match_std: 196, i.e. 0.77%
# AWAY_TEAM_PENALTIES_5_last_match_std: 195, i.e. 0.77%
# HOME_TEAM_REDCARDS_5_last_match_sum: 148, i.e. 0.58%
# HOME_TEAM_REDCARDS_5_last_match_average: 148, i.e. 0.58%
# AWAY_TEAM_REDCARDS_5_last_match_sum: 147, i.e. 0.58%
# AWAY_TEAM_REDCARDS_5_last_match_average: 147, i.e. 0.58%
# AWAY_TEAM_REDCARDS_5_last_match_std: 146, i.e. 0.58%
# HOME_TEAM_REDCARDS_5_last_match_std: 145, i.e. 0.57%
# HOME_TEAM_PENALTIES_5_last_match_sum: 115, i.e. 0.45%
# HOME_TEAM_PENALTIES_5_last_match_average: 113, i.e. 0.45%
# AWAY_TEAM_PENALTIES_5_last_match_sum: 111, i.e. 0.44%
# AWAY_TEAM_PENALTIES_5_last_match_average: 109, i.e. 0.43%
# AWAY_TEAM_ATTACKS_5_last_match_std: 68, i.e. 0.27%
# AWAY_TEAM_DANGEROUS_ATTACKS_5_last_match_std: 68, i.e. 0.27%
# AWAY_TEAM_PENALTIES_season_std: 67, i.e. 0.26%
# HOME_TEAM_PENALTIES_season_std: 66, i.e. 0.26%
# HOME_TEAM_DANGEROUS_ATTACKS_5_last_match_std: 62, i.e. 0.24%
# HOME_TEAM_ATTACKS_5_last_match_std: 62, i.e. 0.24%
# AWAY_TEAM_REDCARDS_season_average: 53, i.e. 0.21%
# HOME_TEAM_REDCARDS_season_average: 53, i.e. 0.21%
# AWAY_TEAM_REDCARDS_season_sum: 53, i.e. 0.21%
# HOME_TEAM_REDCARDS_season_sum: 53, i.e. 0.21%
# AWAY_TEAM_REDCARDS_season_std: 49, i.e. 0.19%
# HOME_TEAM_REDCARDS_season_std: 49, i.e. 0.19%
# AWAY_TEAM_SUBSTITUTIONS_season_average: 47, i.e. 0.19%
# AWAY_TEAM_PENALTIES_season_sum: 47, i.e. 0.19%
# HOME_TEAM_SUBSTITUTIONS_season_average: 47, i.e. 0.19%
# HOME_TEAM_PENALTIES_season_sum: 45, i.e. 0.18%
# HOME_TEAM_SUBSTITUTIONS_season_std: 45, i.e. 0.18%
# AWAY_TEAM_PENALTIES_season_average: 45, i.e. 0.18%
# AWAY_TEAM_SUBSTITUTIONS_season_std: 44, i.e. 0.17%
# HOME_TEAM_PENALTIES_season_average: 43, i.e. 0.17%
# AWAY_TEAM_SUBSTITUTIONS_season_sum: 42, i.e. 0.17%
# HOME_TEAM_SUBSTITUTIONS_season_sum: 42, i.e. 0.17%
# AWAY_TEAM_GAME_DRAW_season_sum: 32, i.e. 0.13%
# HOME_TEAM_GAME_DRAW_season_sum: 32, i.e. 0.13%
# HOME_TEAM_GAME_DRAW_5_last_match_sum: 29, i.e. 0.11%
# AWAY_TEAM_GAME_DRAW_5_last_match_average: 29, i.e. 0.11%
# HOME_TEAM_GAME_DRAW_5_last_match_average: 29, i.e. 0.11%
# AWAY_TEAM_GAME_DRAW_5_last_match_sum: 29, i.e. 0.11%
# AWAY_TEAM_GAME_DRAW_season_average: 28, i.e. 0.11%
# HOME_TEAM_GAME_DRAW_season_average: 28, i.e. 0.11%
# AWAY_TEAM_ATTACKS_5_last_match_average: 22, i.e. 0.09%
# AWAY_TEAM_DANGEROUS_ATTACKS_5_last_match_sum: 22, i.e. 0.09%
# AWAY_TEAM_DANGEROUS_ATTACKS_5_last_match_average: 22, i.e. 0.09%
# AWAY_TEAM_ATTACKS_5_last_match_sum: 22, i.e. 0.09%
# AWAY_TEAM_GAME_LOST_5_last_match_sum: 21, i.e. 0.08%
# HOME_TEAM_GAME_LOST_5_last_match_sum: 21, i.e. 0.08%
# HOME_TEAM_GAME_LOST_season_sum: 21, i.e. 0.08%
# AWAY_TEAM_GAME_LOST_season_sum: 21, i.e. 0.08%
# AWAY_TEAM_GAME_LOST_5_last_match_average: 21, i.e. 0.08%
# HOME_TEAM_GAME_LOST_5_last_match_average: 21, i.e. 0.08%
# HOME_TEAM_GAME_LOST_season_average: 20, i.e. 0.08%
# AWAY_TEAM_GAME_LOST_season_average: 20, i.e. 0.08%
# HOME_TEAM_GAME_WON_season_average: 17, i.e. 0.07%
# AWAY_TEAM_GAME_WON_5_last_match_sum: 17, i.e. 0.07%
# AWAY_TEAM_GAME_WON_season_sum: 17, i.e. 0.07%
# HOME_TEAM_ATTACKS_5_last_match_average: 17, i.e. 0.07%
# HOME_TEAM_DANGEROUS_ATTACKS_5_last_match_average: 17, i.e. 0.07%
# HOME_TEAM_GAME_WON_5_last_match_sum: 17, i.e. 0.07%
# AWAY_TEAM_GAME_WON_season_average: 17, i.e. 0.07%
# HOME_TEAM_GAME_WON_season_sum: 17, i.e. 0.07%
# HOME_TEAM_ATTACKS_5_last_match_sum: 17, i.e. 0.07%
# HOME_TEAM_GAME_WON_5_last_match_average: 17, i.e. 0.07%
# AWAY_TEAM_GAME_WON_5_last_match_average: 17, i.e. 0.07%
# HOME_TEAM_DANGEROUS_ATTACKS_5_last_match_sum: 17, i.e. 0.07%
# AWAY_TEAM_GOALS_5_last_match_std: 11, i.e. 0.04%
# HOME_TEAM_GOALS_5_last_match_std: 11, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_5_last_match_average: 10, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_5_last_match_sum: 10, i.e. 0.04%
# HOME_TEAM_GOALS_season_std: 9, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_season_sum: 9, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_season_sum: 9, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_season_average: 9, i.e. 0.04%
# HOME_TEAM_YELLOWCARDS_season_average: 9, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_5_last_match_average: 9, i.e. 0.04%
# AWAY_TEAM_YELLOWCARDS_5_last_match_sum: 9, i.e. 0.04%
# HOME_TEAM_GOALS_5_last_match_average: 8, i.e. 0.03%
# HOME_TEAM_GOALS_5_last_match_sum: 8, i.e. 0.03%
# AWAY_TEAM_GOALS_season_std: 8, i.e. 0.03%
# AWAY_TEAM_GOALS_season_sum: 7, i.e. 0.03%
# HOME_TEAM_GOALS_season_average: 7, i.e. 0.03%
# HOME_TEAM_GOALS_season_sum: 7, i.e. 0.03%
# AWAY_TEAM_GOALS_5_last_match_average: 7, i.e. 0.03%
# AWAY_TEAM_GOALS_season_average: 7, i.e. 0.03%
# AWAY_TEAM_YELLOWCARDS_5_last_match_std: 7, i.e. 0.03%
# AWAY_TEAM_GOALS_5_last_match_sum: 7, i.e. 0.03%
# HOME_TEAM_YELLOWCARDS_5_last_match_std: 5, i.e. 0.02%
# HOME_TEAM_YELLOWCARDS_season_std: 4, i.e. 0.02%
# AWAY_TEAM_YELLOWCARDS_season_std: 4, i.e. 0.02%
# HOME_TEAM_SHOTS_ON_TARGET_season_sum: 3, i.e. 0.01%
# AWAY_TEAM_SHOTS_ON_TARGET_season_sum: 3, i.e. 0.01%
# HOME_TEAM_SHOTS_ON_TARGET_5_last_match_sum: 3, i.e. 0.01%
# AWAY_TEAM_SHOTS_ON_TARGET_5_last_match_average: 3, i.e. 0.01%
# HOME_TEAM_SHOTS_ON_TARGET_5_last_match_average: 3, i.e. 0.01%
# AWAY_TEAM_SHOTS_ON_TARGET_season_average: 3, i.e. 0.01%
# AWAY_TEAM_SHOTS_ON_TARGET_5_last_match_sum: 3, i.e. 0.01%
# HOME_TEAM_SHOTS_ON_TARGET_season_average: 3, i.e. 0.01%
# HOME_TEAM_CORNERS_season_average: 2, i.e. 0.01%
# AWAY_TEAM_SHOTS_OFF_TARGET_season_average: 2, i.e. 0.01%
# HOME_TEAM_SHOTS_ON_TARGET_season_std: 2, i.e. 0.01%
# AWAY_TEAM_DANGEROUS_ATTACKS_season_std: 2, i.e. 0.01%
# AWAY_TEAM_SHOTS_OFF_TARGET_season_sum: 2, i.e. 0.01%
# AWAY_TEAM_SHOTS_ON_TARGET_5_last_match_std: 2, i.e. 0.01%
# AWAY_TEAM_CORNERS_season_average: 2, i.e. 0.01%
# AWAY_TEAM_ATTACKS_season_std: 2, i.e. 0.01%
# AWAY_TEAM_SHOTS_ON_TARGET_season_std: 2, i.e. 0.01%
# HOME_TEAM_CORNERS_season_sum: 2, i.e. 0.01%
# HOME_TEAM_SHOTS_OFF_TARGET_season_sum: 2, i.e. 0.01%
# HOME_TEAM_SHOTS_OFF_TARGET_season_average: 2, i.e. 0.01%
# HOME_TEAM_DANGEROUS_ATTACKS_season_std: 2, i.e. 0.01%
# AWAY_TEAM_CORNERS_5_last_match_average: 2, i.e. 0.01%
# HOME_TEAM_ATTACKS_season_std: 2, i.e. 0.01%
# HOME_TEAM_SHOTS_ON_TARGET_5_last_match_std: 2, i.e. 0.01%
# AWAY_TEAM_CORNERS_season_sum: 2, i.e. 0.01%
# AWAY_TEAM_BALL_POSSESSION_5_last_match_std: 2, i.e. 0.01%
# HOME_TEAM_CORNERS_5_last_match_average: 2, i.e. 0.01%
# HOME_TEAM_SHOTS_OFF_TARGET_5_last_match_average: 2, i.e. 0.01%
# AWAY_TEAM_SHOTS_OFF_TARGET_5_last_match_sum: 2, i.e. 0.01%
# HOME_TEAM_CORNERS_5_last_match_sum: 2, i.e. 0.01%
# AWAY_TEAM_SHOTS_OFF_TARGET_5_last_match_average: 2, i.e. 0.01%
# HOME_TEAM_SHOTS_OFF_TARGET_5_last_match_sum: 2, i.e. 0.01%
# AWAY_TEAM_CORNERS_5_last_match_sum: 2, i.e. 0.01%
# AWAY_TEAM_CORNERS_5_last_match_std: 1, i.e. 0.00%
# HOME_TEAM_CORNERS_season_std: 1, i.e. 0.00%
# HOME_TEAM_CORNERS_5_last_match_std: 1, i.e. 0.00%
# AWAY_TEAM_CORNERS_season_std: 1, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_5_last_match_std: 0, i.e. 0.00%
# HOME_ID: 0, i.e. 0.00%
# AWAY_TEAM_BALL_POSSESSION_5_last_match_average: 0, i.e. 0.00%
# HOME_TEAM_BALL_POSSESSION_5_last_match_average: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_season_sum: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_season_sum: 0, i.e. 0.00%
# HOME_TEAM_BALL_POSSESSION_season_average: 0, i.e. 0.00%
# HOME_TEAM_ATTACKS_season_average: 0, i.e. 0.00%
# HOME_TEAM_DANGEROUS_ATTACKS_season_average: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_season_std: 0, i.e. 0.00%
# HOME_TEAM_BALL_POSSESSION_season_std: 0, i.e. 0.00%
# HOME_TEAM_SHOTS_OFF_TARGET_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_BALL_POSSESSION_season_std: 0, i.e. 0.00%
# HOME_TEAM_BALL_POSSESSION_5_last_match_std: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_season_sum: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_season_sum: 0, i.e. 0.00%
# AWAY_TEAM_BALL_POSSESSION_season_average: 0, i.e. 0.00%
# AWAY_TEAM_ATTACKS_season_average: 0, i.e. 0.00%
# AWAY_TEAM_DANGEROUS_ATTACKS_season_average: 0, i.e. 0.00%
# AWAY_TEAM_SHOTS_OFF_TARGET_season_std: 0, i.e. 0.00%
# AWAY_ID: 0, i.e. 0.00%

# %%
print("Number of data for train playersfeatures home: ", df_playersfeatures_train_home.shape[0])
print("Number of missing values per column for train playersfeatures home, for non-zero values, sorted by number of missing values in descending order")
serie = df_playersfeatures_train_home.isnull().sum()
serie = serie.sort_values(ascending=False)
for i in range(len(serie)):
    print(f"{serie.index[i]}: {serie[i]}, i.e. {serie[i] / df_playersfeatures_train_home.shape[0] * 100:.2f}%")
# Out:
# Number of data for train playersfeatures home:  237079
# Number of missing values per column for train playersfeatures home, for non-zero values, sorted by number of missing values in descending order
# PLAYER_LONG_BALLS_season_std: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_5_last_match_sum: 237079, i.e. 100.00%
# PLAYER_SHOTS_OFF_TARGET_season_sum: 237079, i.e. 100.00%
# PLAYER_CAPTAIN_season_average: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_season_average: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_WON_season_average: 237079, i.e. 100.00%
# PLAYER_SHOTS_OFF_TARGET_season_average: 237079, i.e. 100.00%
# PLAYER_CAPTAIN_season_std: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_WON_season_std: 237079, i.e. 100.00%
# PLAYER_SHOTS_OFF_TARGET_season_std: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_WON_5_last_match_sum: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_season_sum: 237079, i.e. 100.00%
# PLAYER_SHOTS_OFF_TARGET_5_last_match_sum: 237079, i.e. 100.00%
# PLAYER_CAPTAIN_5_last_match_average: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_5_last_match_average: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_WON_5_last_match_average: 237079, i.e. 100.00%
# PLAYER_SHOTS_OFF_TARGET_5_last_match_average: 237079, i.e. 100.00%
# PLAYER_CAPTAIN_5_last_match_std: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_5_last_match_std: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_WON_5_last_match_std: 237079, i.e. 100.00%
# PLAYER_LONG_BALLS_WON_season_sum: 237079, i.e. 100.00%
# PLAYER_SHOTS_OFF_TARGET_5_last_match_std: 237079, i.e. 100.00%
# PLAYER_CAPTAIN_5_last_match_sum: 219006, i.e. 92.38%
# PLAYER_CAPTAIN_season_sum: 211789, i.e. 89.33%
# PLAYER_PUNCHES_season_std: 170579, i.e. 71.95%
# PLAYER_PUNCHES_5_last_match_std: 170579, i.e. 71.95%
# PLAYER_PUNCHES_season_sum: 169599, i.e. 71.54%
# PLAYER_PUNCHES_5_last_match_sum: 169599, i.e. 71.54%
# PLAYER_PUNCHES_season_average: 169599, i.e. 71.54%
# PLAYER_PUNCHES_5_last_match_average: 169599, i.e. 71.54%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_std: 95161, i.e. 40.14%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_season_std: 81891, i.e. 34.54%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_average: 77848, i.e. 32.84%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_season_average: 70539, i.e. 29.75%
# PLAYER_DRIBBLED_ATTEMPTS_season_std: 56915, i.e. 24.01%
# PLAYER_DRIBBLED_PAST_season_std: 56915, i.e. 24.01%
# PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_std: 56915, i.e. 24.01%
# PLAYER_SUCCESSFUL_DRIBBLES_season_std: 56915, i.e. 24.01%
# PLAYER_DRIBBLED_ATTEMPTS_5_last_match_std: 56915, i.e. 24.01%
# PLAYER_DRIBBLED_PAST_5_last_match_std: 56915, i.e. 24.01%
# PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_sum: 54107, i.e. 22.82%
# PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_average: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_PAST_season_average: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_ATTEMPTS_season_average: 54107, i.e. 22.82%
# PLAYER_SUCCESSFUL_DRIBBLES_season_average: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_ATTEMPTS_season_sum: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_PAST_5_last_match_sum: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_PAST_season_sum: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_PAST_5_last_match_average: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_ATTEMPTS_5_last_match_average: 54107, i.e. 22.82%
# PLAYER_SUCCESSFUL_DRIBBLES_season_sum: 54107, i.e. 22.82%
# PLAYER_DRIBBLED_ATTEMPTS_5_last_match_sum: 54107, i.e. 22.82%
# PLAYER_PENALTIES_SAVED_5_last_match_std: 52274, i.e. 22.05%
# PLAYER_PENALTIES_SAVED_5_last_match_average: 49297, i.e. 20.79%
# PLAYER_PENALTIES_SAVED_5_last_match_sum: 49297, i.e. 20.79%
# POSITION: 42820, i.e. 18.06%
# PLAYER_PENALTIES_SAVED_season_std: 39274, i.e. 16.57%
# PLAYER_PENALTIES_SAVED_season_sum: 36105, i.e. 15.23%
# PLAYER_PENALTIES_SAVED_season_average: 36105, i.e. 15.23%
# PLAYER_CLEARANCE_OFFLINE_5_last_match_std: 35661, i.e. 15.04%
# PLAYER_RATING_season_std: 34503, i.e. 14.55%
# PLAYER_RATING_5_last_match_std: 34503, i.e. 14.55%
# PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_std: 34158, i.e. 14.41%
# PLAYER_PENALTIES_WON_5_last_match_std: 33882, i.e. 14.29%
# PLAYER_PENALTIES_COMMITTED_5_last_match_std: 33600, i.e. 14.17%
# PLAYER_ERROR_LEAD_TO_GOAL_season_std: 33337, i.e. 14.06%
# PLAYER_CLEARANCE_OFFLINE_season_std: 33301, i.e. 14.05%
# PLAYER_DUELS_LOST_season_std: 33247, i.e. 14.02%
# PLAYER_BIG_CHANCES_CREATED_season_std: 33247, i.e. 14.02%
# PLAYER_BIG_CHANCES_MISSED_season_std: 33247, i.e. 14.02%
# PLAYER_BLOCKED_SHOTS_season_std: 33247, i.e. 14.02%
# PLAYER_BLOCKED_SHOTS_5_last_match_std: 33247, i.e. 14.02%
# PLAYER_BIG_CHANCES_MISSED_5_last_match_std: 33247, i.e. 14.02%
# PLAYER_DUELS_LOST_5_last_match_std: 33247, i.e. 14.02%
# PLAYER_BIG_CHANCES_CREATED_5_last_match_std: 33247, i.e. 14.02%
# PLAYER_OFFSIDES_season_std: 33094, i.e. 13.96%
# PLAYER_OFFSIDES_5_last_match_std: 33094, i.e. 13.96%
# PLAYER_PENALTIES_WON_season_std: 32668, i.e. 13.78%
# PLAYER_PENALTIES_COMMITTED_season_std: 32652, i.e. 13.77%
# PLAYER_CLEARANCE_OFFLINE_5_last_match_sum: 32335, i.e. 13.64%
# PLAYER_CLEARANCE_OFFLINE_5_last_match_average: 32335, i.e. 13.64%
# PLAYER_HIT_WOODWORK_5_last_match_std: 32025, i.e. 13.51%
# PLAYER_HIT_WOODWORK_season_std: 31722, i.e. 13.38%
# PLAYER_DUELS_WON_season_std: 31686, i.e. 13.37%
# PLAYER_PASSES_season_std: 31686, i.e. 13.37%
# PLAYER_SHOTS_TOTAL_season_std: 31686, i.e. 13.37%
# PLAYER_SHOTS_BLOCKED_season_std: 31686, i.e. 13.37%
# PLAYER_SAVES_INSIDE_BOX_season_std: 31686, i.e. 13.37%
# PLAYER_ACCURATE_CROSSES_season_std: 31686, i.e. 13.37%
# PLAYER_AERIALS_WON_season_std: 31686, i.e. 13.37%
# PLAYER_SAVES_season_std: 31686, i.e. 13.37%
# PLAYER_KEY_PASSES_season_std: 31686, i.e. 13.37%
# PLAYER_TOTAL_CROSSES_season_std: 31686, i.e. 13.37%
# PLAYER_INTERCEPTIONS_season_std: 31686, i.e. 13.37%
# PLAYER_FOULS_DRAWN_season_std: 31686, i.e. 13.37%
# PLAYER_FOULS_season_std: 31686, i.e. 13.37%
# PLAYER_CLEARANCES_season_std: 31686, i.e. 13.37%
# PLAYER_TACKLES_season_std: 31686, i.e. 13.37%
# PLAYER_DISPOSSESSED_season_std: 31686, i.e. 13.37%
# PLAYER_TOTAL_DUELS_season_std: 31686, i.e. 13.37%
# PLAYER_SHOTS_ON_TARGET_season_std: 31686, i.e. 13.37%
# PLAYER_ACCURATE_PASSES_season_std: 31686, i.e. 13.37%
# PLAYER_FOULS_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_INTERCEPTIONS_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_CLEARANCES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_AERIALS_WON_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_TACKLES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_ACCURATE_PASSES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_ACCURATE_CROSSES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_SHOTS_BLOCKED_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_DUELS_WON_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_FOULS_DRAWN_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_DISPOSSESSED_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_TOTAL_CROSSES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_SHOTS_TOTAL_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_SHOTS_ON_TARGET_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_KEY_PASSES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_TOTAL_DUELS_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_PASSES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_SAVES_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_SAVES_INSIDE_BOX_5_last_match_std: 31686, i.e. 13.37%
# PLAYER_RATING_season_average: 31168, i.e. 13.15%
# PLAYER_RATING_5_last_match_average: 31168, i.e. 13.15%
# PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_average: 30824, i.e. 13.00%
# PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_sum: 30824, i.e. 13.00%
# PLAYER_PENALTIES_WON_5_last_match_average: 30529, i.e. 12.88%
# PLAYER_PENALTIES_WON_5_last_match_sum: 30529, i.e. 12.88%
# PLAYER_PENALTIES_COMMITTED_5_last_match_sum: 30243, i.e. 12.76%
# PLAYER_PENALTIES_COMMITTED_5_last_match_average: 30243, i.e. 12.76%
# PLAYER_ERROR_LEAD_TO_GOAL_season_sum: 29985, i.e. 12.65%
# PLAYER_ERROR_LEAD_TO_GOAL_season_average: 29985, i.e. 12.65%
# PLAYER_CLEARANCE_OFFLINE_season_sum: 29949, i.e. 12.63%
# PLAYER_CLEARANCE_OFFLINE_season_average: 29949, i.e. 12.63%
# PLAYER_BIG_CHANCES_CREATED_season_average: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_MISSED_season_average: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_MISSED_season_sum: 29895, i.e. 12.61%
# PLAYER_BLOCKED_SHOTS_season_average: 29895, i.e. 12.61%
# PLAYER_DUELS_LOST_season_sum: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_CREATED_season_sum: 29895, i.e. 12.61%
# PLAYER_DUELS_LOST_season_average: 29895, i.e. 12.61%
# PLAYER_BLOCKED_SHOTS_5_last_match_average: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_CREATED_5_last_match_sum: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_MISSED_5_last_match_sum: 29895, i.e. 12.61%
# PLAYER_BLOCKED_SHOTS_5_last_match_sum: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_MISSED_5_last_match_average: 29895, i.e. 12.61%
# PLAYER_BLOCKED_SHOTS_season_sum: 29895, i.e. 12.61%
# PLAYER_DUELS_LOST_5_last_match_sum: 29895, i.e. 12.61%
# PLAYER_BIG_CHANCES_CREATED_5_last_match_average: 29895, i.e. 12.61%
# PLAYER_DUELS_LOST_5_last_match_average: 29895, i.e. 12.61%
# PLAYER_OFFSIDES_season_sum: 29742, i.e. 12.55%
# PLAYER_OFFSIDES_5_last_match_sum: 29742, i.e. 12.55%
# PLAYER_OFFSIDES_5_last_match_average: 29742, i.e. 12.55%
# PLAYER_OFFSIDES_season_average: 29742, i.e. 12.55%
# PLAYER_PENALTIES_WON_season_sum: 29304, i.e. 12.36%
# PLAYER_PENALTIES_WON_season_average: 29304, i.e. 12.36%
# PLAYER_PENALTIES_COMMITTED_season_sum: 29287, i.e. 12.35%
# PLAYER_PENALTIES_COMMITTED_season_average: 29287, i.e. 12.35%
# PLAYER_HIT_WOODWORK_5_last_match_average: 28629, i.e. 12.08%
# PLAYER_HIT_WOODWORK_5_last_match_sum: 28629, i.e. 12.08%
# PLAYER_HIT_WOODWORK_season_average: 28325, i.e. 11.95%
# PLAYER_HIT_WOODWORK_season_sum: 28325, i.e. 11.95%
# PLAYER_TACKLES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_TOTAL_DUELS_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_TOTAL_CROSSES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_SHOTS_ON_TARGET_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_SHOTS_TOTAL_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_ACCURATE_PASSES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_AERIALS_WON_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_ACCURATE_CROSSES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_FOULS_DRAWN_season_sum: 28289, i.e. 11.93%
# PLAYER_CLEARANCES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_BLOCKED_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_ACCURATE_CROSSES_season_sum: 28289, i.e. 11.93%
# PLAYER_ACCURATE_PASSES_season_sum: 28289, i.e. 11.93%
# PLAYER_AERIALS_WON_season_sum: 28289, i.e. 11.93%
# PLAYER_TOTAL_DUELS_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_TOTAL_CROSSES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_TACKLES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_TOTAL_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_ON_TARGET_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SAVES_INSIDE_BOX_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_DISPOSSESSED_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SAVES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SAVES_INSIDE_BOX_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_PASSES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_KEY_PASSES_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_INTERCEPTIONS_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_FOULS_DRAWN_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_FOULS_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_DUELS_WON_5_last_match_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_BLOCKED_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_CLEARANCES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_SAVES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_AERIALS_WON_season_average: 28289, i.e. 11.93%
# PLAYER_TOTAL_CROSSES_season_average: 28289, i.e. 11.93%
# PLAYER_TACKLES_season_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_TOTAL_season_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_ON_TARGET_season_average: 28289, i.e. 11.93%
# PLAYER_SHOTS_BLOCKED_season_average: 28289, i.e. 11.93%
# PLAYER_SAVES_INSIDE_BOX_season_average: 28289, i.e. 11.93%
# PLAYER_PASSES_season_average: 28289, i.e. 11.93%
# PLAYER_KEY_PASSES_season_average: 28289, i.e. 11.93%
# PLAYER_INTERCEPTIONS_season_average: 28289, i.e. 11.93%
# PLAYER_FOULS_DRAWN_season_average: 28289, i.e. 11.93%
# PLAYER_FOULS_season_average: 28289, i.e. 11.93%
# PLAYER_DUELS_WON_season_average: 28289, i.e. 11.93%
# PLAYER_DISPOSSESSED_season_average: 28289, i.e. 11.93%
# PLAYER_CLEARANCES_season_average: 28289, i.e. 11.93%
# PLAYER_ACCURATE_PASSES_season_average: 28289, i.e. 11.93%
# PLAYER_DISPOSSESSED_season_sum: 28289, i.e. 11.93%
# PLAYER_ACCURATE_CROSSES_season_average: 28289, i.e. 11.93%
# PLAYER_DUELS_WON_season_sum: 28289, i.e. 11.93%
# PLAYER_FOULS_season_sum: 28289, i.e. 11.93%
# PLAYER_TOTAL_DUELS_season_sum: 28289, i.e. 11.93%
# PLAYER_TOTAL_CROSSES_season_sum: 28289, i.e. 11.93%
# PLAYER_TACKLES_season_sum: 28289, i.e. 11.93%
# PLAYER_SHOTS_TOTAL_season_sum: 28289, i.e. 11.93%
# PLAYER_SHOTS_ON_TARGET_season_sum: 28289, i.e. 11.93%
# PLAYER_SHOTS_BLOCKED_season_sum: 28289, i.e. 11.93%
# PLAYER_SAVES_INSIDE_BOX_season_sum: 28289, i.e. 11.93%
# PLAYER_SAVES_season_sum: 28289, i.e. 11.93%
# PLAYER_PASSES_season_sum: 28289, i.e. 11.93%
# PLAYER_KEY_PASSES_season_sum: 28289, i.e. 11.93%
# PLAYER_INTERCEPTIONS_season_sum: 28289, i.e. 11.93%
# PLAYER_TOTAL_DUELS_season_average: 28289, i.e. 11.93%
# PLAYER_SAVES_season_average: 28289, i.e. 11.93%
# PLAYER_FOULS_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_FOULS_DRAWN_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_CLEARANCES_season_sum: 28289, i.e. 11.93%
# PLAYER_KEY_PASSES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_ACCURATE_CROSSES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_ACCURATE_PASSES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_AERIALS_WON_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_PASSES_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_DISPOSSESSED_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_INTERCEPTIONS_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_DUELS_WON_5_last_match_sum: 28289, i.e. 11.93%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_season_std: 23797, i.e. 10.04%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_std: 23797, i.e. 10.04%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_season_sum: 20320, i.e. 8.57%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_average: 20320, i.e. 8.57%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_season_average: 20320, i.e. 8.57%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_sum: 20320, i.e. 8.57%
# PLAYER_PENALTIES_MISSES_5_last_match_std: 13390, i.e. 5.65%
# PLAYER_REDCARDS_5_last_match_std: 10939, i.e. 4.61%
# PLAYER_PENALTIES_MISSES_5_last_match_average: 9664, i.e. 4.08%
# PLAYER_PENALTIES_MISSES_5_last_match_sum: 9664, i.e. 4.08%
# PLAYER_OWN_GOALS_5_last_match_std: 8658, i.e. 3.65%
# PLAYER_PENALTIES_MISSES_season_std: 8531, i.e. 3.60%
# PLAYER_REDCARDS_season_std: 8118, i.e. 3.42%
# PLAYER_OWN_GOALS_season_std: 7689, i.e. 3.24%
# PLAYER_GOALS_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_MINUTES_PLAYED_season_std: 7443, i.e. 3.14%
# PLAYER_GOALS_CONCEDED_season_std: 7443, i.e. 3.14%
# PLAYER_GOALS_season_std: 7443, i.e. 3.14%
# PLAYER_ASSISTS_season_std: 7443, i.e. 3.14%
# PLAYER_MINUTES_PLAYED_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_YELLOWCARDS_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_YELLOWCARDS_season_std: 7443, i.e. 3.14%
# PLAYER_ASSISTS_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_PENALTIES_SCORED_season_std: 7443, i.e. 3.14%
# PLAYER_PENALTIES_SCORED_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_STARTING_LINEUP_season_std: 7443, i.e. 3.14%
# PLAYER_GOALS_CONCEDED_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_STARTING_LINEUP_5_last_match_std: 7443, i.e. 3.14%
# PLAYER_REDCARDS_5_last_match_average: 7200, i.e. 3.04%
# PLAYER_REDCARDS_5_last_match_sum: 7200, i.e. 3.04%
# PLAYER_OWN_GOALS_5_last_match_average: 4842, i.e. 2.04%
# PLAYER_OWN_GOALS_5_last_match_sum: 4842, i.e. 2.04%
# PLAYER_PENALTIES_MISSES_season_sum: 4721, i.e. 1.99%
# PLAYER_PENALTIES_MISSES_season_average: 4721, i.e. 1.99%
# PLAYER_REDCARDS_season_sum: 4318, i.e. 1.82%
# PLAYER_REDCARDS_season_average: 4318, i.e. 1.82%
# PLAYER_OWN_GOALS_season_average: 3858, i.e. 1.63%
# PLAYER_OWN_GOALS_season_sum: 3858, i.e. 1.63%
# PLAYER_MINUTES_PLAYED_5_last_match_sum: 3597, i.e. 1.52%
# PLAYER_PENALTIES_SCORED_season_sum: 3597, i.e. 1.52%
# PLAYER_MINUTES_PLAYED_season_sum: 3597, i.e. 1.52%
# PLAYER_STARTING_LINEUP_5_last_match_sum: 3597, i.e. 1.52%
# PLAYER_YELLOWCARDS_5_last_match_sum: 3597, i.e. 1.52%
# PLAYER_PENALTIES_SCORED_5_last_match_sum: 3597, i.e. 1.52%
# PLAYER_GOALS_CONCEDED_season_sum: 3597, i.e. 1.52%
# PLAYER_GOALS_season_sum: 3597, i.e. 1.52%
# PLAYER_GOALS_CONCEDED_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_ASSISTS_5_last_match_sum: 3597, i.e. 1.52%
# PLAYER_STARTING_LINEUP_season_sum: 3597, i.e. 1.52%
# PLAYER_MINUTES_PLAYED_season_average: 3597, i.e. 1.52%
# PLAYER_MINUTES_PLAYED_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_GOALS_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_PENALTIES_SCORED_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_YELLOWCARDS_season_average: 3597, i.e. 1.52%
# PLAYER_STARTING_LINEUP_season_average: 3597, i.e. 1.52%
# PLAYER_STARTING_LINEUP_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_YELLOWCARDS_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_GOALS_CONCEDED_5_last_match_sum: 3597, i.e. 1.52%
# PLAYER_PENALTIES_SCORED_season_average: 3597, i.e. 1.52%
# PLAYER_GOALS_CONCEDED_season_average: 3597, i.e. 1.52%
# PLAYER_GOALS_season_average: 3597, i.e. 1.52%
# PLAYER_ASSISTS_season_sum: 3597, i.e. 1.52%
# PLAYER_ASSISTS_season_average: 3597, i.e. 1.52%
# PLAYER_ASSISTS_5_last_match_average: 3597, i.e. 1.52%
# PLAYER_YELLOWCARDS_season_sum: 3597, i.e. 1.52%
# PLAYER_GOALS_5_last_match_sum: 3597, i.e. 1.52%
# LEAGUE: 0, i.e. 0.00%
# PLAYER_NAME: 0, i.e. 0.00%
# TEAM_NAME: 0, i.e. 0.00%
# ID_team: 0, i.e. 0.00%

# %%
print("Number of data for test playersfeatures home: ", df_playersfeatures_test_home.shape[0])
print("Number of missing values per column for test playersfeatures home, sorted by number of missing values in descending order")
serie = df_playersfeatures_test_home.isnull().sum()
serie = serie.sort_values(ascending=False)
for i in range(len(serie)):
    print(f"{serie.index[i]}: {serie[i]}, i.e. {serie[i] / df_playersfeatures_test_home.shape[0] * 100:.2f}%")
# Out:
# Number of data for test playersfeatures home:  509816
# Number of missing values per column for test playersfeatures home, sorted by number of missing values in descending order
# PLAYER_CAPTAIN_5_last_match_std: 509816, i.e. 100.00%
# PLAYER_CAPTAIN_season_average: 509816, i.e. 100.00%
# PLAYER_CAPTAIN_5_last_match_average: 509816, i.e. 100.00%
# PLAYER_CAPTAIN_season_std: 509816, i.e. 100.00%
# PLAYER_CAPTAIN_5_last_match_sum: 471607, i.e. 92.51%
# PLAYER_CAPTAIN_season_sum: 455890, i.e. 89.42%
# PLAYER_LONG_BALLS_WON_season_std: 341389, i.e. 66.96%
# PLAYER_LONG_BALLS_WON_5_last_match_std: 341389, i.e. 66.96%
# PLAYER_LONG_BALLS_5_last_match_std: 341389, i.e. 66.96%
# PLAYER_LONG_BALLS_season_std: 341389, i.e. 66.96%
# PLAYER_LONG_BALLS_season_average: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_WON_season_average: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_WON_season_sum: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_5_last_match_sum: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_season_sum: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_WON_5_last_match_sum: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_5_last_match_average: 338923, i.e. 66.48%
# PLAYER_LONG_BALLS_WON_5_last_match_average: 338923, i.e. 66.48%
# PLAYER_SHOTS_OFF_TARGET_5_last_match_std: 338664, i.e. 66.43%
# PLAYER_SHOTS_OFF_TARGET_season_std: 337512, i.e. 66.20%
# PLAYER_SHOTS_OFF_TARGET_5_last_match_sum: 336179, i.e. 65.94%
# PLAYER_SHOTS_OFF_TARGET_5_last_match_average: 336179, i.e. 65.94%
# PLAYER_SHOTS_OFF_TARGET_season_sum: 335012, i.e. 65.71%
# PLAYER_SHOTS_OFF_TARGET_season_average: 335012, i.e. 65.71%
# PLAYER_PUNCHES_5_last_match_std: 168715, i.e. 33.09%
# PLAYER_PUNCHES_season_std: 167883, i.e. 32.93%
# PLAYER_PUNCHES_5_last_match_average: 163146, i.e. 32.00%
# PLAYER_PUNCHES_5_last_match_sum: 163146, i.e. 32.00%
# PLAYER_PUNCHES_season_average: 162298, i.e. 31.83%
# PLAYER_PUNCHES_season_sum: 162298, i.e. 31.83%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_std: 156633, i.e. 30.72%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_average: 113966, i.e. 22.35%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_season_std: 112472, i.e. 22.06%
# PLAYER_ACCURATE_PASSES_PERCENTAGE_season_average: 87661, i.e. 17.19%
# PLAYER_PENALTIES_SAVED_5_last_match_std: 73861, i.e. 14.49%
# PLAYER_PENALTIES_SAVED_5_last_match_sum: 66440, i.e. 13.03%
# PLAYER_PENALTIES_SAVED_5_last_match_average: 66440, i.e. 13.03%
# PLAYER_SUCCESSFUL_DRIBBLES_season_std: 58100, i.e. 11.40%
# PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_std: 58100, i.e. 11.40%
# PLAYER_DRIBBLED_ATTEMPTS_5_last_match_std: 58100, i.e. 11.40%
# PLAYER_DRIBBLED_ATTEMPTS_season_std: 58100, i.e. 11.40%
# PLAYER_DRIBBLED_PAST_season_std: 58100, i.e. 11.40%
# PLAYER_DRIBBLED_PAST_5_last_match_std: 58100, i.e. 11.40%
# POSITION: 54500, i.e. 10.69%
# PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_average: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_PAST_season_average: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_PAST_5_last_match_average: 50536, i.e. 9.91%
# PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_sum: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_ATTEMPTS_5_last_match_average: 50536, i.e. 9.91%
# PLAYER_SUCCESSFUL_DRIBBLES_season_sum: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_PAST_5_last_match_sum: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_ATTEMPTS_5_last_match_sum: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_ATTEMPTS_season_sum: 50536, i.e. 9.91%
# PLAYER_SUCCESSFUL_DRIBBLES_season_average: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_PAST_season_sum: 50536, i.e. 9.91%
# PLAYER_DRIBBLED_ATTEMPTS_season_average: 50536, i.e. 9.91%
# PLAYER_CLEARANCE_OFFLINE_5_last_match_std: 49400, i.e. 9.69%
# PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_std: 43205, i.e. 8.47%
# PLAYER_CLEARANCE_OFFLINE_5_last_match_average: 41558, i.e. 8.15%
# PLAYER_CLEARANCE_OFFLINE_5_last_match_sum: 41558, i.e. 8.15%
# PLAYER_ERROR_LEAD_TO_GOAL_season_std: 41292, i.e. 8.10%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_season_std: 40932, i.e. 8.03%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_std: 40932, i.e. 8.03%
# PLAYER_PENALTIES_SAVED_season_std: 39324, i.e. 7.71%
# PLAYER_RATING_season_std: 38550, i.e. 7.56%
# PLAYER_RATING_5_last_match_std: 38550, i.e. 7.56%
# PLAYER_PENALTIES_WON_5_last_match_std: 38164, i.e. 7.49%
# PLAYER_PENALTIES_COMMITTED_5_last_match_std: 37630, i.e. 7.38%
# PLAYER_BLOCKED_SHOTS_5_last_match_std: 37155, i.e. 7.29%
# PLAYER_CLEARANCE_OFFLINE_season_std: 37091, i.e. 7.28%
# PLAYER_HIT_WOODWORK_5_last_match_std: 37057, i.e. 7.27%
# PLAYER_BIG_CHANCES_CREATED_5_last_match_std: 36984, i.e. 7.25%
# PLAYER_BIG_CHANCES_MISSED_5_last_match_std: 36872, i.e. 7.23%
# PLAYER_SAVES_INSIDE_BOX_5_last_match_std: 36050, i.e. 7.07%
# PLAYER_SAVES_5_last_match_std: 35826, i.e. 7.03%
# PLAYER_ACCURATE_CROSSES_5_last_match_std: 35619, i.e. 6.99%
# PLAYER_INTERCEPTIONS_5_last_match_std: 35147, i.e. 6.89%
# PLAYER_BLOCKED_SHOTS_season_std: 35134, i.e. 6.89%
# PLAYER_DUELS_LOST_5_last_match_std: 35122, i.e. 6.89%
# PLAYER_DUELS_LOST_season_std: 35122, i.e. 6.89%
# PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_average: 34706, i.e. 6.81%
# PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_sum: 34706, i.e. 6.81%
# PLAYER_BIG_CHANCES_MISSED_season_std: 34640, i.e. 6.79%
# PLAYER_BIG_CHANCES_CREATED_season_std: 34601, i.e. 6.79%
# PLAYER_TOTAL_CROSSES_5_last_match_std: 34425, i.e. 6.75%
# PLAYER_KEY_PASSES_5_last_match_std: 34425, i.e. 6.75%
# PLAYER_PENALTIES_WON_season_std: 34287, i.e. 6.73%
# PLAYER_PENALTIES_COMMITTED_season_std: 34145, i.e. 6.70%
# PLAYER_DISPOSSESSED_season_std: 33919, i.e. 6.65%
# PLAYER_AERIALS_WON_season_std: 33919, i.e. 6.65%
# PLAYER_AERIALS_WON_5_last_match_std: 33919, i.e. 6.65%
# PLAYER_DISPOSSESSED_5_last_match_std: 33919, i.e. 6.65%
# PLAYER_HIT_WOODWORK_season_std: 33613, i.e. 6.59%
# PLAYER_SAVES_INSIDE_BOX_season_std: 33613, i.e. 6.59%
# PLAYER_TACKLES_season_std: 33595, i.e. 6.59%
# PLAYER_DUELS_WON_season_std: 33595, i.e. 6.59%
# PLAYER_CLEARANCES_season_std: 33595, i.e. 6.59%
# PLAYER_DUELS_WON_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_OFFSIDES_season_std: 33595, i.e. 6.59%
# PLAYER_TOTAL_DUELS_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_FOULS_season_std: 33595, i.e. 6.59%
# PLAYER_CLEARANCES_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_SHOTS_TOTAL_season_std: 33595, i.e. 6.59%
# PLAYER_FOULS_DRAWN_season_std: 33595, i.e. 6.59%
# PLAYER_ACCURATE_PASSES_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_PASSES_season_std: 33595, i.e. 6.59%
# PLAYER_INTERCEPTIONS_season_std: 33595, i.e. 6.59%
# PLAYER_TACKLES_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_FOULS_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_FOULS_DRAWN_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_SHOTS_ON_TARGET_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_SHOTS_ON_TARGET_season_std: 33595, i.e. 6.59%
# PLAYER_SHOTS_BLOCKED_season_std: 33595, i.e. 6.59%
# PLAYER_SAVES_season_std: 33595, i.e. 6.59%
# PLAYER_SHOTS_BLOCKED_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_TOTAL_CROSSES_season_std: 33595, i.e. 6.59%
# PLAYER_TOTAL_DUELS_season_std: 33595, i.e. 6.59%
# PLAYER_ACCURATE_CROSSES_season_std: 33595, i.e. 6.59%
# PLAYER_ACCURATE_PASSES_season_std: 33595, i.e. 6.59%
# PLAYER_SHOTS_TOTAL_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_PASSES_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_OFFSIDES_5_last_match_std: 33595, i.e. 6.59%
# PLAYER_KEY_PASSES_season_std: 33595, i.e. 6.59%
# PLAYER_ERROR_LEAD_TO_GOAL_season_average: 33295, i.e. 6.53%
# PLAYER_ERROR_LEAD_TO_GOAL_season_sum: 33295, i.e. 6.53%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_sum: 33032, i.e. 6.48%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_average: 33032, i.e. 6.48%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_season_sum: 33032, i.e. 6.48%
# PLAYER_GOALKEEPER_GOALS_CONCEDED_season_average: 33032, i.e. 6.48%
# PLAYER_PENALTIES_SAVED_season_average: 31369, i.e. 6.15%
# PLAYER_PENALTIES_SAVED_season_sum: 31369, i.e. 6.15%
# PLAYER_RATING_5_last_match_average: 30483, i.e. 5.98%
# PLAYER_RATING_season_average: 30483, i.e. 5.98%
# PLAYER_PENALTIES_WON_5_last_match_sum: 30069, i.e. 5.90%
# PLAYER_PENALTIES_WON_5_last_match_average: 30069, i.e. 5.90%
# PLAYER_PENALTIES_COMMITTED_5_last_match_average: 29547, i.e. 5.80%
# PLAYER_PENALTIES_COMMITTED_5_last_match_sum: 29547, i.e. 5.80%
# PLAYER_CLEARANCE_OFFLINE_season_sum: 29117, i.e. 5.71%
# PLAYER_CLEARANCE_OFFLINE_season_average: 29117, i.e. 5.71%
# PLAYER_BLOCKED_SHOTS_5_last_match_sum: 29027, i.e. 5.69%
# PLAYER_BLOCKED_SHOTS_5_last_match_average: 29027, i.e. 5.69%
# PLAYER_HIT_WOODWORK_5_last_match_average: 28966, i.e. 5.68%
# PLAYER_HIT_WOODWORK_5_last_match_sum: 28966, i.e. 5.68%
# PLAYER_BIG_CHANCES_CREATED_5_last_match_average: 28927, i.e. 5.67%
# PLAYER_BIG_CHANCES_CREATED_5_last_match_sum: 28927, i.e. 5.67%
# PLAYER_BIG_CHANCES_MISSED_5_last_match_sum: 28817, i.e. 5.65%
# PLAYER_BIG_CHANCES_MISSED_5_last_match_average: 28817, i.e. 5.65%
# PLAYER_OWN_GOALS_5_last_match_std: 28658, i.e. 5.62%
# PLAYER_SAVES_INSIDE_BOX_5_last_match_sum: 27952, i.e. 5.48%
# PLAYER_SAVES_INSIDE_BOX_5_last_match_average: 27952, i.e. 5.48%
# PLAYER_SAVES_5_last_match_average: 27726, i.e. 5.44%
# PLAYER_SAVES_5_last_match_sum: 27726, i.e. 5.44%
# PLAYER_ACCURATE_CROSSES_5_last_match_sum: 27512, i.e. 5.40%
# PLAYER_ACCURATE_CROSSES_5_last_match_average: 27512, i.e. 5.40%
# PLAYER_BLOCKED_SHOTS_season_sum: 27071, i.e. 5.31%
# PLAYER_BLOCKED_SHOTS_season_average: 27071, i.e. 5.31%
# PLAYER_DUELS_LOST_season_sum: 27052, i.e. 5.31%
# PLAYER_DUELS_LOST_season_average: 27052, i.e. 5.31%
# PLAYER_DUELS_LOST_5_last_match_sum: 27052, i.e. 5.31%
# PLAYER_DUELS_LOST_5_last_match_average: 27052, i.e. 5.31%
# PLAYER_INTERCEPTIONS_5_last_match_average: 27017, i.e. 5.30%
# PLAYER_INTERCEPTIONS_5_last_match_sum: 27017, i.e. 5.30%
# PLAYER_BIG_CHANCES_MISSED_season_sum: 26546, i.e. 5.21%
# PLAYER_BIG_CHANCES_MISSED_season_average: 26546, i.e. 5.21%
# PLAYER_BIG_CHANCES_CREATED_season_sum: 26507, i.e. 5.20%
# PLAYER_BIG_CHANCES_CREATED_season_average: 26507, i.e. 5.20%
# PLAYER_KEY_PASSES_5_last_match_sum: 26287, i.e. 5.16%
# PLAYER_KEY_PASSES_5_last_match_average: 26287, i.e. 5.16%
# PLAYER_TOTAL_CROSSES_5_last_match_average: 26287, i.e. 5.16%
# PLAYER_TOTAL_CROSSES_5_last_match_sum: 26287, i.e. 5.16%
# PLAYER_PENALTIES_WON_season_average: 26142, i.e. 5.13%
# PLAYER_PENALTIES_WON_season_sum: 26142, i.e. 5.13%
# PLAYER_PENALTIES_COMMITTED_season_average: 26015, i.e. 5.10%
# PLAYER_PENALTIES_COMMITTED_season_sum: 26015, i.e. 5.10%
# PLAYER_PENALTIES_MISSES_5_last_match_std: 25902, i.e. 5.08%
# PLAYER_AERIALS_WON_season_sum: 25793, i.e. 5.06%
# PLAYER_AERIALS_WON_season_average: 25793, i.e. 5.06%
# PLAYER_DISPOSSESSED_5_last_match_average: 25793, i.e. 5.06%
# PLAYER_DISPOSSESSED_season_sum: 25793, i.e. 5.06%
# PLAYER_DISPOSSESSED_season_average: 25793, i.e. 5.06%
# PLAYER_AERIALS_WON_5_last_match_average: 25793, i.e. 5.06%
# PLAYER_DISPOSSESSED_5_last_match_sum: 25793, i.e. 5.06%
# PLAYER_AERIALS_WON_5_last_match_sum: 25793, i.e. 5.06%
# PLAYER_HIT_WOODWORK_season_sum: 25475, i.e. 5.00%
# PLAYER_SAVES_INSIDE_BOX_season_sum: 25475, i.e. 5.00%
# PLAYER_SAVES_INSIDE_BOX_season_average: 25475, i.e. 5.00%
# PLAYER_HIT_WOODWORK_season_average: 25475, i.e. 5.00%
# PLAYER_TACKLES_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_TACKLES_season_average: 25457, i.e. 4.99%
# PLAYER_FOULS_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_FOULS_DRAWN_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_TACKLES_season_sum: 25457, i.e. 4.99%
# PLAYER_TOTAL_CROSSES_season_sum: 25457, i.e. 4.99%
# PLAYER_KEY_PASSES_season_sum: 25457, i.e. 4.99%
# PLAYER_INTERCEPTIONS_season_sum: 25457, i.e. 4.99%
# PLAYER_ACCURATE_CROSSES_season_sum: 25457, i.e. 4.99%
# PLAYER_ACCURATE_PASSES_season_sum: 25457, i.e. 4.99%
# PLAYER_TOTAL_DUELS_season_sum: 25457, i.e. 4.99%
# PLAYER_CLEARANCES_season_average: 25457, i.e. 4.99%
# PLAYER_OFFSIDES_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_PASSES_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_TOTAL_CROSSES_season_average: 25457, i.e. 4.99%
# PLAYER_FOULS_DRAWN_season_average: 25457, i.e. 4.99%
# PLAYER_FOULS_DRAWN_season_sum: 25457, i.e. 4.99%
# PLAYER_TOTAL_DUELS_season_average: 25457, i.e. 4.99%
# PLAYER_DUELS_WON_season_average: 25457, i.e. 4.99%
# PLAYER_FOULS_season_sum: 25457, i.e. 4.99%
# PLAYER_DUELS_WON_season_sum: 25457, i.e. 4.99%
# PLAYER_FOULS_season_average: 25457, i.e. 4.99%
# PLAYER_ACCURATE_PASSES_season_average: 25457, i.e. 4.99%
# PLAYER_SHOTS_BLOCKED_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_TOTAL_DUELS_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_DUELS_WON_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_SHOTS_TOTAL_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_ACCURATE_CROSSES_season_average: 25457, i.e. 4.99%
# PLAYER_SHOTS_ON_TARGET_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_TACKLES_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_TOTAL_DUELS_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_ACCURATE_PASSES_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_BLOCKED_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_ON_TARGET_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_TOTAL_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_PASSES_season_average: 25457, i.e. 4.99%
# PLAYER_SAVES_season_sum: 25457, i.e. 4.99%
# PLAYER_PASSES_season_sum: 25457, i.e. 4.99%
# PLAYER_PASSES_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_BLOCKED_season_sum: 25457, i.e. 4.99%
# PLAYER_CLEARANCES_season_sum: 25457, i.e. 4.99%
# PLAYER_SAVES_season_average: 25457, i.e. 4.99%
# PLAYER_OFFSIDES_season_average: 25457, i.e. 4.99%
# PLAYER_OFFSIDES_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_CLEARANCES_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_ACCURATE_PASSES_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_FOULS_DRAWN_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_ON_TARGET_season_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_TOTAL_season_sum: 25457, i.e. 4.99%
# PLAYER_SHOTS_BLOCKED_season_average: 25457, i.e. 4.99%
# PLAYER_SHOTS_ON_TARGET_season_average: 25457, i.e. 4.99%
# PLAYER_SHOTS_TOTAL_season_average: 25457, i.e. 4.99%
# PLAYER_CLEARANCES_5_last_match_average: 25457, i.e. 4.99%
# PLAYER_KEY_PASSES_season_average: 25457, i.e. 4.99%
# PLAYER_FOULS_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_DUELS_WON_5_last_match_sum: 25457, i.e. 4.99%
# PLAYER_INTERCEPTIONS_season_average: 25457, i.e. 4.99%
# PLAYER_OFFSIDES_season_sum: 25457, i.e. 4.99%
# PLAYER_OWN_GOALS_season_std: 22784, i.e. 4.47%
# PLAYER_PENALTIES_MISSES_season_std: 20571, i.e. 4.03%
# PLAYER_OWN_GOALS_5_last_match_sum: 20480, i.e. 4.02%
# PLAYER_OWN_GOALS_5_last_match_average: 20480, i.e. 4.02%
# PLAYER_REDCARDS_5_last_match_std: 19601, i.e. 3.84%
# PLAYER_REDCARDS_season_std: 18089, i.e. 3.55%
# PLAYER_PENALTIES_MISSES_5_last_match_sum: 17650, i.e. 3.46%
# PLAYER_PENALTIES_MISSES_5_last_match_average: 17650, i.e. 3.46%
# PLAYER_ASSISTS_5_last_match_std: 16947, i.e. 3.32%
# PLAYER_ASSISTS_season_std: 16844, i.e. 3.30%
# PLAYER_GOALS_CONCEDED_5_last_match_std: 16804, i.e. 3.30%
# PLAYER_MINUTES_PLAYED_5_last_match_std: 16804, i.e. 3.30%
# PLAYER_YELLOWCARDS_5_last_match_std: 16804, i.e. 3.30%
# PLAYER_STARTING_LINEUP_5_last_match_std: 16804, i.e. 3.30%
# PLAYER_PENALTIES_SCORED_5_last_match_std: 16804, i.e. 3.30%
# PLAYER_GOALS_5_last_match_std: 16804, i.e. 3.30%
# PLAYER_MINUTES_PLAYED_season_std: 16804, i.e. 3.30%
# PLAYER_GOALS_CONCEDED_season_std: 16804, i.e. 3.30%
# PLAYER_GOALS_season_std: 16804, i.e. 3.30%
# PLAYER_PENALTIES_SCORED_season_std: 16804, i.e. 3.30%
# PLAYER_STARTING_LINEUP_season_std: 16804, i.e. 3.30%
# PLAYER_YELLOWCARDS_season_std: 16804, i.e. 3.30%
# PLAYER_OWN_GOALS_season_sum: 14527, i.e. 2.85%
# PLAYER_OWN_GOALS_season_average: 14527, i.e. 2.85%
# PLAYER_PENALTIES_MISSES_season_average: 12210, i.e. 2.39%
# PLAYER_PENALTIES_MISSES_season_sum: 12210, i.e. 2.39%
# PLAYER_REDCARDS_5_last_match_average: 10941, i.e. 2.15%
# PLAYER_REDCARDS_5_last_match_sum: 10941, i.e. 2.15%
# PLAYER_REDCARDS_season_sum: 9476, i.e. 1.86%
# PLAYER_REDCARDS_season_average: 9476, i.e. 1.86%
# PLAYER_ASSISTS_5_last_match_average: 8470, i.e. 1.66%
# PLAYER_ASSISTS_5_last_match_sum: 8470, i.e. 1.66%
# PLAYER_ASSISTS_season_sum: 8365, i.e. 1.64%
# PLAYER_ASSISTS_season_average: 8365, i.e. 1.64%
# PLAYER_PENALTIES_SCORED_season_sum: 8322, i.e. 1.63%
# PLAYER_MINUTES_PLAYED_season_sum: 8322, i.e. 1.63%
# PLAYER_GOALS_season_sum: 8322, i.e. 1.63%
# PLAYER_STARTING_LINEUP_season_average: 8322, i.e. 1.63%
# PLAYER_YELLOWCARDS_season_average: 8322, i.e. 1.63%
# PLAYER_GOALS_CONCEDED_season_sum: 8322, i.e. 1.63%
# PLAYER_PENALTIES_SCORED_season_average: 8322, i.e. 1.63%
# PLAYER_MINUTES_PLAYED_5_last_match_sum: 8322, i.e. 1.63%
# PLAYER_GOALS_5_last_match_sum: 8322, i.e. 1.63%
# PLAYER_GOALS_5_last_match_average: 8322, i.e. 1.63%
# PLAYER_YELLOWCARDS_5_last_match_average: 8322, i.e. 1.63%
# PLAYER_STARTING_LINEUP_5_last_match_average: 8322, i.e. 1.63%
# PLAYER_PENALTIES_SCORED_5_last_match_average: 8322, i.e. 1.63%
# PLAYER_YELLOWCARDS_season_sum: 8322, i.e. 1.63%
# PLAYER_MINUTES_PLAYED_5_last_match_average: 8322, i.e. 1.63%
# PLAYER_GOALS_CONCEDED_5_last_match_average: 8322, i.e. 1.63%
# PLAYER_STARTING_LINEUP_season_sum: 8322, i.e. 1.63%
# PLAYER_GOALS_CONCEDED_5_last_match_sum: 8322, i.e. 1.63%
# PLAYER_GOALS_season_average: 8322, i.e. 1.63%
# PLAYER_GOALS_CONCEDED_season_average: 8322, i.e. 1.63%
# PLAYER_MINUTES_PLAYED_season_average: 8322, i.e. 1.63%
# PLAYER_YELLOWCARDS_5_last_match_sum: 8322, i.e. 1.63%
# PLAYER_STARTING_LINEUP_5_last_match_sum: 8322, i.e. 1.63%
# PLAYER_PENALTIES_SCORED_5_last_match_sum: 8322, i.e. 1.63%
# ID: 0, i.e. 0.00%
